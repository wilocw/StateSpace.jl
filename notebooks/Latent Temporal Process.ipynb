# %%
include("GP.jl");
using PyPlot

# %% [markdown]
# $f_t(u,\lambda) = \lambda\tanh(u)$
#
# $\lambda(t) = 1 + \sin(\omega t)$

# %%
𝑓ₜ(𝑢,𝜆) = tanh.(𝜆.*𝑢)# + 𝜆[2]
𝜆(𝑡) = 1. + sin.(ω.*𝑡)#, cos.(ω.*𝑡)]

𝑛ₜ = 100
ω  = 8π
𝑛ᵤ = 25

𝐭 = linspace(0.,1.,𝑛ₜ)
𝐮 = linspace(-10.,10.,500)
# Out:
# -10.0:0.04008016032064128:10.0

# %%
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f80039c7358>)
# 1-element Array{PyCall.PyObject,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x7f800392e4a8>

# %%
plot(𝐭,𝜆(𝐭),"--")
#plot(𝐭,𝜆(𝐭)[2],"--")

xlabel(L"$t$")
ylabel(L"$\lambda(t)$")

𝐟ₜ = [𝑓ₜ(𝐮,𝜆(𝑡)) for 𝑡 ∈ 𝐭]
lbl = []
figure()
for 𝑖 ∈ [1;10:10:𝑛ₜ]
    plot(𝐮, 𝐟ₜ[𝑖])
    txt = @sprintf "%s=%3d, %s=%4.2f, %s=(%4.2f,%4.2f)" L"$i$" 𝑖 L"$t$" 𝐭[𝑖] L"$\lambda$" 𝜆(𝐭[𝑖])[1] 𝜆(𝐭[𝑖])[2]
    push!(lbl,txt)
end
xlabel(L"$u$")
ylabel(L"$f_t(u,\lambda(t))$")
legend(labels=lbl)

; #suppress text output
# Out:
# BoundsError
#
# Stacktrace:
#  [1] getindex(::Float64, ::Int64) at ./number.jl:38
#  [2] macro expansion at ./In[43]:12 [inlined]
#  [3] anonymous at ./<missing>:?
#  [4] include_string(::String, ::String) at ./loading.jl:522

# %%
figure()
for 𝑖 ∈ [1;10:10:𝑛ₜ]
    plot3D(𝐮, repmat([𝐭[𝑖]],length(𝐮),1),𝐟ₜ[𝑖])
end
xlabel(L"$u$")
ylabel(L"$t$")
zlabel(L"$f_t(u,\lambda(t))$")
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f8003693710>)
# PyObject Text(0.0910982,0.0122048,'$f_t(u,\\lambda(t))$')

# %%
function sample(𝐮,𝐟ₜ;𝜎²=1e-10,𝑠ₜ=10,𝑠ᵤ=5)
    𝑛ₜ = length(𝐟ₜ)
    𝑡ᵢ = round.(Int,linspace(1,𝑛ₜ,𝑠ₜ))
    
    𝐟ᵢ = 𝐟ₜ[𝑡ᵢ]
    
    uₜ = [rand(1:floor(Int,𝑛ₜ),𝑠ᵤ) for _ ∈ 1:𝑠ₜ]
    𝐲 = [𝐟ᵢ[𝑡][uₜ[𝑡]] + sqrt.(𝜎²)*randn() for 𝑡 ∈ 1:𝑠ₜ]
    
    return uₜ, 𝐲, 𝑡ᵢ
end
# Out:
# sample (generic function with 1 method)

# %%
𝑄 = 0.1^2
uₜ, 𝐲, 𝑡ᵢ = sample(𝐮,𝐟ₜ,𝜎²=𝑄)

for 𝑖 ∈ 𝑡ᵢ
    gp_predict = trained_gp(uₜ[𝑖],𝐲[𝑖],σ²=𝑄)
    
    μ,Σ = gp_predict(𝐮)
    
    
    figure()
    plot(𝐮, 𝐟ₜ[𝑖],"-",uₜ[𝑖],𝐲[𝑖],".")
    
    plot(𝐮, μ, "--")
    fill_between(𝐮,
                 μ - 1.96*sqrt.(diag(Σ)), 
                 μ + 1.96*sqrt.(diag(Σ)), alpha=0.5)
end
# Out:
# BoundsError: attempt to access 10-element Array{Array{Int64,1},1} at index [12]
#
# Stacktrace:
#  [1] getindex(::Array{Array{Int64,1},1}, ::Int64) at .\array.jl:554
#  [2] macro expansion at .\In[62]:5 [inlined]
#  [3] anonymous at .\<missing>:?
#  [4] include_string(::String, ::String) at .\loading.jl:522

# %%
# Out:
# 10-element Array{Int64,1}:
#    1
#   12
#   23
#   34
#   45
#   56
#   67
#   78
#   89
#  100
