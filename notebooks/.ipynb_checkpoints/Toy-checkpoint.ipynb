# %% [markdown]
# # Spatial-temporal Toy problem
# $f_t(\mathbf{u},\lambda) = \lambda_x(\vec{x} - 0.5)^2 - \lambda_y(\vec{y} - 0.5)^2$
#
# $\mathbf{u} = \begin{bmatrix}\vec{x}\\\vec{y}\end{bmatrix}, \qquad \lambda(t) = \begin{bmatrix}\lambda_x(t)\\\lambda_y(t)\end{bmatrix} = \begin{bmatrix}2 + \sin(\omega t)\\ 2 - \sin(\omega t)\end{bmatrix}$
#
# $y_t = f_t(\mathbf{u},\lambda(t)) + \nu_t,\qquad \nu_t\sim\mathcal{N}(0,\mathbf{Q}_t)$

# %%
function fₜ(𝐮,λ)
    𝑥,𝑦 = 𝐮
    return λ[1]*(𝑥 - 0.5).^2 - λ[2]*(𝑦 - 0.5).^2
end
# Out:
# fₜ (generic function with 1 method)

# %%
𝑛ₜ = 100
Δᵤ = 50
𝑛ᵤ = 25
ω  = 8π ;

# %%
𝑡 = linspace(0,1,𝑛ₜ)


𝛌 = [2 + sin.(ω.*𝑡),
     2 - sin.(ω.*𝑡)]

using PyPlot
plot(𝑡, 𝛌[1],"-",
     𝑡, 𝛌[2],"-")

legend(labels=[L"$\lambda_x$",L"$\lambda_y$"])
xlabel(L"$t$"), ylabel(L"$\lambda$")
title(L"$\omega = 8\pi$")
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x0000000023A00F98>)
# PyObject <matplotlib.text.Text object at 0x00000000271D7198>

# %%
𝐮 = (repmat(linspace(0.,1.,Δᵤ)',Δᵤ,1), repmat(linspace(0.,1.,Δᵤ),1,Δᵤ))

𝐐 = 0.1.^2

𝐟 = map(λ -> fₜ(𝐮,λ), zip(𝛌[1],𝛌[2]))
𝐲 = map(λ -> fₜ(𝐮,λ) + chol(𝐐)*randn((Δᵤ,Δᵤ)), zip(𝛌[1],𝛌[2]))

; # terminate output

# %%
# Plot all 
function plot_all()
    for i ∈ [1;10:10:100]
        figure(figsize=(15,6))
        title(i)
        subplot(121)
        pcolor(𝐮[1],𝐮[2],𝐟[i])
        clim([-1., 1.])
        colorbar()
        subplot(122)
        pcolor(𝐮[1],𝐮[2],𝐲[i])
        colorbar()
        clim([-1., 1.])
    end
end

#plot_all()

# %%
function sample(𝐲,𝑛ᵤ=10)
    s = rand(1:floor(Int,Δᵤ),𝑛ᵤ,2)
    s = zip(s[:,1],s[:,2])
    u = zeros((𝑛ᵤ,2))
    u[:,1] = [𝐮[1][𝑖,𝑗] for (𝑖,𝑗) ∈ s]
    u[:,2] = [𝐮[2][𝑖,𝑗] for (𝑖,𝑗) ∈ s]
    y      = [𝐲[𝑖,𝑗]    for (𝑖,𝑗) ∈ s]
    return u,y
end

# %%
u,y = sample(𝐲[1])

plot(u[:,1],u[:,2],".")

# %%
function kern_rbf(𝑥ᵢ, 𝑥ⱼ;
                  ls = NaN,
                  v  = NaN,
                  θ::Dict = Dict("lengthscale" => 1.,
                                 "variance"    => 1.))
    
    
    if !isnan(ls)
        θ["lengthscale"] = convert(Float64,ls)
    end
    
    if !isnan(v)
        θ["variance"]    = convert(Float64, v)
    end
    
    if length(𝑥ᵢ) != length(𝑥ⱼ)
        println("error: input dimensions incorrect")
        return NaN
    end
    
#     if length(θ["lengthscale"]) < length(𝑥ᵢ)
#         θnew = Dict("lengthscale" => θ["lengthscale"][1]*eye(length(length(𝑥ᵢ))))
#         θnew["variance"] = θ["variance"]
#         θ = θnew
#     end
    
#     if length(θ["variance"]) < length(𝑥ᵢ)
#         θ["variance"] = 
#         θnew = Dict("variance" => θ["variance"][1]*eye(length(length(𝑥ᵢ))))
#         θnew["lengthscale"] = θ["lengthscale"]
#         θ = θnew
#     end
    
    𝑘 = θ["variance"] .* exp(-norm(𝑥ᵢ - 𝑥ⱼ).^2 ./ θ["lengthscale"]^2)
    
    return 𝑘
end

function kern_linear(𝑥ᵢ, 𝑥ⱼ;
                     b = NaN,
                     v = NaN,
                     c = NaN,
                     θ::Dict{String,Float64} = Dict("constant_variance" => 0.,
                                                    "offset"      => 1.,
                                                    "variance"    => 1.))
    
    if !isnan(b)
        θ["constant_variance"] = convert(Float64,b)
    end
    if !isnan(c)
        θ["offset"]            = convert(Float64,c)
    end
    if !isnan(v)
        θ["variance"]          = convert(Float64, v)
    end
    
    𝑘 = θ["constant_variance"] 
            + θ["variance"] * (𝑥ᵢ - θ["offset"]) * (𝑥ⱼ - θ["offset"])
    
    return 𝑘
end

function kern_periodic(𝑥ᵢ, 𝑥ⱼ;
                       p  = NaN,
                       ls = NaN,
                       v  = NaN,
                       θ::Dict{String,Float64} = Dict("period"      => 1., 
                                                      "lengthscale" => 0.1,
                                                      "variance"    => 1.))
    if !isnan(p)
        θ["period"] = convert(Float64,p)
    end
    if !isnan(ls)
        θ["lengthscale"] = convert(Float64,ls)
    end
    if !isnan(v)
        θ["variance"]    = convert(Float64, v)
    end
    
    𝑘 = θ["variance"] * exp(-(2*sin(π*norm(𝑥ᵢ - 𝑥ⱼ)/θ["period"])^2) 
                              / θ["lengthscale"]^2)
    
    return 𝑘
    
end

function kern_exponential_𝛾(𝑥ᵢ, 𝑥ⱼ;
                            𝛾  = NaN,
                            ls = NaN,
                            v  = NaN,
                            θ::Dict{String,Float64} = Dict("exponent"    => 1., 
                                                           "lengthscale" => 0.1,
                                                           "variance"    => 1.))
    if !isnan(𝛾)
        θ["exponent"] = convert(Float64, 𝛾)
    end
    if !isnan(ls)
        θ["lengthscale"] = convert(Float64, ls)
    end
    if !isnan(v)
        θ["variance"]    = convert(Float64, v)
    end
    
    𝑘 = θ["variance"] .* exp(-(norm(𝑥ᵢ - 𝑥ⱼ)./θ["lengthscale"]).^θ["exponent"])
    
    return 𝑘
end
    
function kern_exponential(𝑥ᵢ, 𝑥ⱼ;
                          ls = NaN,
                          v  = NaN,
                          θ::Dict{String,Float64} = Dict("lengthscale" => 0.1,
                                                           "variance"    => 1.))
    return kern_exponential_𝛾(𝑥ᵢ, 𝑥ⱼ, 𝛾 = 1., ls = ls, v = v, θ = θ)
end
# Out:
# kern_exponential (generic function with 1 method)

# %%
function sample_kernel(𝐱; 𝑘 = kern_rbf, θ = nothing)
    
    𝑛ₓ = length(𝐱)
    
    if θ == nothing
        𝐊ₛₛ = reshape([𝑘(𝑥ᵢ, 𝑥ⱼ) for 𝑥ᵢ ∈ 𝐱 for 𝑥ⱼ ∈ 𝐱], 𝑛ₓ, 𝑛ₓ)
    else
        𝐊ₛₛ = reshape([𝑘(𝑥ᵢ, 𝑥ⱼ, θ=θ) for 𝑥ᵢ ∈ 𝐱 for 𝑥ⱼ ∈ 𝐱], 𝑛ₓ, 𝑛ₓ)
    end
     
    
    U,S,V = svd(𝐊ₛₛ)
    𝐿 = U * diagm(sqrt.(S))
                    
    return 𝐿*randn((𝑛ₓ,1))
end
# Out:
# sample_kernel (generic function with 1 method)

# %%
x = linspace(-1.5,1.5,400)

params = Dict("lengthscale" => 0.25, "variance" => 1.)
                                
figure()
for _ ∈ 1:5
    plot(x,sample_kernel(x,𝑘 = kern_rbf,θ = params))
end
title("exponentiated quadratic")    

params = Dict("period" => 1., "lengthscale" => 0.25, "variance" => 1.)
figure()
for i ∈ [1.,2.,4.]
    params["period"] = i
    plot(x,sample_kernel(x, 𝑘 = kern_periodic, θ = params))
end
title("periodic")
legend(labels=[1.,2.,4.])


params = Dict("lengthscale" => 0.5, "variance" => 1.)
figure()
for _ ∈ 1:5
    plot(x,sample_kernel(x, 𝑘 = kern_exponential, θ = params))
end
title("exponential")

params = Dict("exponent" => 1.,"lengthscale" => 0.5, "variance" => 1.)

figure()
for params["exponent"] ∈ [1.,2.,4.,10.]
    plot(x,sample_kernel(x, 𝑘 = kern_exponential_𝛾, θ = params))
end
title(L"$\gamma$-exponential")
legend(labels=[1.,2.,4.,10.])
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x00000000283C06D8>)
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x000000002A51E358>)
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x000000002A574550>)
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x000000002A5D35C0>)
# PyObject <matplotlib.legend.Legend object at 0x000000002A843D68>

# %%
function sample_nd_kernel(𝐮; 𝑘 = kern_rbf, θ = nothing)
    
    𝑛ᵤ = length(𝐮)
    𝑛ₓ = length(𝐮[1][:])
    
    #iterator (2d only)
    u_itr = zip(𝐮[1][:],𝐮[2][:])
    
    if θ == nothing
        𝐊ₛₛ = reshape([𝑘(collect(𝑥ᵢ), collect(𝑥ⱼ))
                        for 𝑥ᵢ ∈ u_itr for 𝑥ⱼ ∈ u_itr], 𝑛ₓ, 𝑛ₓ)
    else
        𝐊ₛₛ = reshape([𝑘(collect(𝑥ᵢ), collect(𝑥ⱼ), θ=θ)
                        for 𝑥ᵢ ∈ u_itr for 𝑥ⱼ ∈ u_itr], 𝑛ₓ, 𝑛ₓ)
    end
    
    U,S,V = svd(𝐊ₛₛ)
    𝐿 = U * diagm(sqrt.(S))
         
    return 𝐿*randn((𝑛ₓ,1))
end

# %%
#Δᵤ = 25
𝐮  = (repmat(linspace(-1.5,1.5,Δᵤ)',Δᵤ,1), repmat(linspace(-1.5,1.5,Δᵤ),1,Δᵤ))

for i = 1:4
    k = reshape(sample_nd_kernel(𝐮), Δᵤ,Δᵤ)
    surf(𝐮[1],𝐮[2],k,alpha=0.2)
end
title("draws from 2-D exponentiated quadratic kernel")

# %%
function trained_gp(uₛ,yₛ;
                    σ² = 0., # default noise-free
                    𝑘 = kern_rbf,
                    θ = Dict("lengthscale"=>0.25, "variance"=>1.))
    
    𝑛ₛ   = size(uₛ,1)
    
    𝐊ₛₛ  = zeros(𝑛ₛ, 𝑛ₛ)
    for 𝑖 ∈ 1:𝑛ₛ
        for 𝑗 ∈ 1:𝑛ₛ
            𝐊ₛₛ[𝑖,𝑗] = 𝑘(uₛ[𝑖,:],uₛ[𝑗,:],θ=θ)
        end
    end
    
#     uᵢₜᵣ = partition(uₛ'[:],size(uₛ,2))
#     𝐊ₛₛ  = reshape([𝑘(collect(𝑥ᵢ), collect(𝑥ⱼ))
#                     for 𝑥ᵢ ∈ uᵢₜᵣ for 𝑥ⱼ ∈ uᵢₜᵣ], 𝑛ₛ, 𝑛ₛ)

    return u -> _proto_gp_predict(u, uₛ, yₛ, 𝐊ₛₛ + σ²*eye(𝑛ₛ), 𝑘, θ)
end
                
function _proto_gp_predict(u, uₛ, yₛ, 𝐊ₛₛ, 𝑘, θ)
    
    𝑛ₛ  = size(uₛ,1)
    𝑛₊  = size(u,1)
    
    𝐊ₛ₊  = zeros(𝑛₊, 𝑛ₛ)
    for 𝑖 ∈ 1:𝑛₊
        for 𝑗 ∈ 1:𝑛ₛ
            𝐊ₛ₊[𝑖,𝑗] = 𝑘(u[𝑖,:],uₛ[𝑗,:],θ=θ)
        end
    end
    
    𝐊₊₊  = zeros(𝑛₊, 𝑛₊)
    for 𝑖 ∈ 1:𝑛₊
        for 𝑗 ∈ 1:𝑛₊
            𝐊₊₊[𝑖,𝑗] = 𝑘(u[𝑖,:],u[𝑗,:],θ=θ)
        end
    end
    
#     uᵢₜᵣ  = partition(uₛ'[:],size(uₛ,2))
#     u⁺ᵢₜᵣ = partition(u'[:],size(u,2))
#     𝐊ₛ₊   = reshape([𝑘(collect(𝑥ᵢ), collect(𝑥ⱼ))
#                             for 𝑥ᵢ ∈ u⁺ᵢₜᵣ for 𝑥ⱼ ∈ uᵢₜᵣ], 𝑛₊, 𝑛ₛ)
#     𝐊₊₊   = reshape([𝑘(collect(𝑥ᵢ), collect(𝑥ⱼ))
#                             for 𝑥ᵢ ∈ u⁺ᵢₜᵣ for 𝑥ⱼ ∈ u⁺ᵢₜᵣ], 𝑛₊, 𝑛₊)
                                                    
    𝛍 = (𝐊ₛ₊ / 𝐊ₛₛ) * yₛ
    𝚺 = 𝐊₊₊ - (𝐊ₛ₊ / 𝐊ₛₛ) * 𝐊ₛ₊'

    return 𝛍, 𝚺
end
# Out:
# _proto_gp_predict (generic function with 1 method)

# %%
#u,y = sample(𝐲[1],50)

u,y = sample(𝐲[1],10)

plot(u[:,1],u[:,2],".")

params = Dict("lengthscale"=>0.2,"variance"=>0.05)

gp_predict = trained_gp(u,y,σ² = 𝐐, θ = params)

fᵐ, fᶜ = gp_predict([𝐮[1][:] 𝐮[2][:]])

;

# %%
matshow(fᶜ); colorbar()

# %%
function plot_prediction(𝐮,𝐟,fᵐ,fᶜ=nothing,u=nothing)
    
    Δx,Δy = size(𝐮[1])
    
    figure()#figsize=(15,8))
    
    if fᶜ == nothing
        subplot(121)
    else
        subplot(311)
    end
    pcolor(𝐮[1],𝐮[2],𝐟)
    clim([-1.,1.])
    title("truth")
    colorbar()
    
    if fᶜ == nothing
        subplot(122)
    else
        subplot(312)
    end
    pcolor(𝐮[1],𝐮[2],reshape(fᵐ,Δx,Δy))
    if u != nothing
        plot(u[:,1],u[:,2],".")
    end
    clim([-1.,1.])
    title("gp mean")
    colorbar()

    if fᶜ != nothing
        subplot(313)
        pcolor(𝐮[1],𝐮[2],reshape(diag(fᶜ),Δx,Δy))
        if u != nothing
            plot(u[:,1],u[:,2],".")
        end
        title("gp variance")
        colorbar()
    end
end

plot_prediction(𝐮,𝐟[1],fᵐ,fᶜ,u)

# figure()
# pcolor(𝐮[1],𝐮[2],fᶜ)
# title("variance")

# %%
function gp_example()
    x = linspace(0,2π,500)
    f = sin.(x)
    
    σ² = 0.1 ^ 2
    
    i = sort(1 + round.(Int, 500 * rand(10)))
    
    u = x[i]
    y = f[i] + sqrt.(σ²) * randn(10)
    
    plot(x,f,"-",u,y,"o")
    
    params = Dict("lengthscale" => 1., "variance" => 0.5)
    
    gp_predict = trained_gp(u, y, 𝑘=kern_exponential,
                                  σ²=σ²,
                                  θ = params)

    μ,Σ = gp_predict(x)
    
    plot(x,μ,"--")
   
    fill_between(x,
                 μ - 1.96*sqrt.(diag(Σ)), 
                 μ + 1.96*sqrt.(diag(Σ)), alpha=0.5)
    
    return μ, Σ
end

μ, Σ = gp_example();
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x000000002AF8C080>)

# %%
function sample_posterior(Σ)
    
    𝑛ₓ = size(Σ,1)
    
    U,S,V = svd(Σ)
    𝐿 = U * diagm(sqrt.(S))
                    
    return 𝐿
end

L = sample_posterior(Σ);

# %%
x_ = linspace(0,2π,500)

plot(x_,sin.(x_),"b--")
for i = 1:100
    plot(x_,μ + L*randn(500),"k",alpha=0.2)
end
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x0000000003494278>)

# %%
#u,y = collect([sample(𝐲[i],10) ])

n = 10
Δ = 5
u = zeros(n * length(𝐲) / Δ,3)
y = zeros(n * length(𝐲) / Δ,1)

for i ∈ 1:Δ:length(𝐲)
    ix = (1:n) + convert(Int,(n/Δ)*(i-1))
    u[ix,1:2], y[ix,:] = sample(𝐲[i],n)
    u[ix,3] = convert(Float64,i)
    
    plot(u[ix,1],u[ix,2],".")
end

params = Dict("lengthscale"=>3,"variance"=>0.05)

gp_predict = trained_gp(u,y,σ² = 𝐐, θ = params)

# %%
t = 50
tst_points = [𝐮[1][:] 𝐮[2][:] repmat([convert(Float64,t)],length(𝐮[1]),1)]

fᵐ, fᶜ = gp_predict(tst_points)

plot_prediction(𝐮,𝐟[t],fᵐ, fᶜ)

# %%
rmse = zeros(𝑛ₜ,1)
vmax = zeros(𝑛ₜ,1)
vmed = zeros(𝑛ₜ,1)


for t = 1:𝑛ₜ
    
    tst_points = [𝐮[1][:] 𝐮[2][:] repmat([convert(Float64,t)],length(𝐮[1]),1)]

    fᵐ, fᶜ = gp_predict(tst_points)
    
    if t % 10 == 0 
        plot_prediction(𝐮,𝐟[t],fᵐ)
    end
    
    rmse[t] = sqrt.(sum((𝐟[t][:] - fᵐ).^2))
    vmax[t] = maximum(diag(fᶜ))
    vmed[t] = median(diag(fᶜ))
end

#plot(rmse,"-",vmax,"-",vmed,"-")

# %%
figure()

subplot(211)
plot(rmse,"-")
xlabel("t"); ylabel("prediction rmse")

subplot(212)
plot(vmax,"-",vmed,"-")
xlabel("t"); ylabel("prediction variance")
legend(labels=["max variance","median variance"])

# %%
function kf()
    q, λ = 1., 1.
    
    μ₀, Σ₀ = 0., q/2λ
    for t = 1:𝑛ₜ
        
        
    end
end
